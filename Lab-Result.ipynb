# %%
# %load_ext autoreload
# %autoreload 2
from LabResultProcessing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
readResult()
# Out:
# Total Center Code: 43
# Total Records with No Region: 0
#
# TAMAN SARI not in result
#        Country Facility Code      Center Code Patient ID         IC No  \
# 0     Malaysia           QDC         SANDAKAN  MRN000677  740518125515
# 1     Malaysia          NUSG     MASJID TANAH        NaN  770331135307
# 2     Malaysia           QDC  SG PETANI UTARA       8694  641116026051
# 3     Malaysia           QDC             MERU        NaN  811009146057
# 4     Malaysia          NUSG    BATU BERENDAM        NaN  760227045433
# ...        ...           ...              ...        ...           ...
# 2486  Malaysia          NUSG       ALOR SETAR        NaN  610730095055
# 2487  Malaysia          NUSG          BANGSAR        NaN  531010106267
# 2488  Malaysia          NUSG      KOTA TINGGI        NaN  671030015252
# 2489  Malaysia          NUSG      KOTA TINGGI        NaN  730302016361
# 2490  Malaysia          NUSG  BANDAR BARU UDA        NaN  550114085687
#
# ...
